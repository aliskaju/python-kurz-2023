# %%
import pandas
platy = pandas.read_csv("platy_2021_02.csv")
platy
# Out:
#     cislo_zamestnance     plat
# 0                   3  54900.0
# 1                   6  54800.0
# 2                   7  36400.0
# 3                   8  47900.0
# 4                  16  34200.0
# 5                  18  35400.0
# 6                  21  54200.0
# 7                  22  34400.0
# 8                  23  39000.0
# 9                  24  44200.0
# 10                 26  59600.0
# 11                 27  45100.0
# 12                 28  38100.0
# 13                 29  48900.0
# 14                 30  33500.0
# 15                 32  53000.0
# 16                 33  38400.0
# 17                 34  36800.0
# 18                 38  32600.0
# 19                 40  32800.0
# 20                 41  49300.0
# 21                 44  52000.0
# 22                 47  40700.0
# 23                 49  58400.0
# 24                 51  37100.0
# 25                 56  39300.0
# 26                 57  36800.0
# 27                 63  31400.0
# 28                 64  36900.0
# ...

# %%
platy["plat"].plot(kind='hist', bins=8, grid=True, subplots=True)
# Out:
# array([<Axes: ylabel='Frequency'>], dtype=object)

# %%
temperature = pandas.read_csv("temperature.csv")
temperature
# Out:
#              Region  Country      City  Day  AvgTemperature
# 0            Africa  Algeria   Algiers    1            62.0
# 1            Africa  Algeria   Algiers    2            62.2
# 2            Africa  Algeria   Algiers    3            65.7
# 3            Africa  Algeria   Algiers    4            69.8
# 4            Africa  Algeria   Algiers    5            63.8
# ...             ...      ...       ...  ...             ...
# 8785  North America       US  Cheyenne   26            51.7
# 8786  North America       US  Cheyenne   27            55.5
# 8787  North America       US  Cheyenne   28            38.5
# 8788  North America       US  Cheyenne   29            36.8
# 8789  North America       US  Cheyenne   30            36.9
#
# [8790 rows x 5 columns]

# %%
tabulka_1 = temperature[temperature["City"].isin(["Helsinki", "Miami Beach", "Tokyo"])]
tabulka_1
# Out:
#              Region Country         City  Day  AvgTemperature
# 1140           Asia   Japan        Tokyo    1            59.1
# 1141           Asia   Japan        Tokyo    2            62.3
# 1142           Asia   Japan        Tokyo    3            64.1
# 1143           Asia   Japan        Tokyo    4            59.6
# 1144           Asia   Japan        Tokyo    5            57.0
# ...             ...     ...          ...  ...             ...
# 5035  North America      US  Miami Beach   26            73.5
# 5036  North America      US  Miami Beach   27            73.1
# 5037  North America      US  Miami Beach   28            77.5
# 5038  North America      US  Miami Beach   29            77.7
# 5039  North America      US  Miami Beach   30            78.0
#
# [90 rows x 5 columns]

# %%
tabulka =pandas.DataFrame(tabulka_1, columns=["City", "AvgTemperature"])
tabulka
# Out:
#              City  AvgTemperature
# 1140        Tokyo            59.1
# 1141        Tokyo            62.3
# 1142        Tokyo            64.1
# 1143        Tokyo            59.6
# 1144        Tokyo            57.0
# ...           ...             ...
# 5035  Miami Beach            73.5
# 5036  Miami Beach            73.1
# 5037  Miami Beach            77.5
# 5038  Miami Beach            77.7
# 5039  Miami Beach            78.0
#
# [90 rows x 2 columns]

# %%
tabulka.plot(kind='box', by = "City")
# Out:
# AvgTemperature    Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %%
tokyo = tabulka[tabulka["City"] == "Tokyo"]
tokyo
# Out:
#        City  AvgTemperature
# 1140  Tokyo            59.1
# 1141  Tokyo            62.3
# 1142  Tokyo            64.1
# 1143  Tokyo            59.6
# 1144  Tokyo            57.0
# 1145  Tokyo            60.4
# 1146  Tokyo            64.0
# 1147  Tokyo            62.5
# 1148  Tokyo            59.0
# 1149  Tokyo            62.1
# 1150  Tokyo            59.5
# 1151  Tokyo            55.1
# 1152  Tokyo            56.8
# 1153  Tokyo            56.2
# 1154  Tokyo            56.7
# 1155  Tokyo            53.7
# 1156  Tokyo            53.1
# 1157  Tokyo            53.5
# 1158  Tokyo            48.9
# 1159  Tokyo            46.6
# 1160  Tokyo            48.2
# 1161  Tokyo            48.7
# 1162  Tokyo            53.4
# 1163  Tokyo            50.3
# 1164  Tokyo            50.5
# 1165  Tokyo            58.8
# 1166  Tokyo            53.8
# 1167  Tokyo            53.8
# 1168  Tokyo            58.4
# 1169  Tokyo            51.5

# %%
miami_beach = tabulka[tabulka["City"] == "Miami Beach"]
miami_beach
# Out:
#              City  AvgTemperature
# 5010  Miami Beach            74.6
# 5011  Miami Beach            76.8
# 5012  Miami Beach            77.4
# 5013  Miami Beach            77.4
# 5014  Miami Beach            77.2
# 5015  Miami Beach            78.6
# 5016  Miami Beach            78.8
# 5017  Miami Beach            79.0
# 5018  Miami Beach            80.0
# 5019  Miami Beach            80.2
# 5020  Miami Beach            79.1
# 5021  Miami Beach            80.8
# 5022  Miami Beach            79.2
# 5023  Miami Beach            79.7
# 5024  Miami Beach            75.4
# 5025  Miami Beach            75.0
# 5026  Miami Beach            73.8
# 5027  Miami Beach            75.1
# 5028  Miami Beach            75.2
# 5029  Miami Beach            74.5
# 5030  Miami Beach            74.4
# 5031  Miami Beach            77.3
# 5032  Miami Beach            77.4
# 5033  Miami Beach            75.9
# 5034  Miami Beach            72.1
# 5035  Miami Beach            73.5
# ...

# %%
helsinki = tabulka[tabulka["City"] == "Helsinki"]
helsinki
# Out:
#           City  AvgTemperature
# 2160  Helsinki            29.6
# 2161  Helsinki            29.5
# 2162  Helsinki            35.1
# 2163  Helsinki            44.5
# 2164  Helsinki            45.5
# 2165  Helsinki            43.8
# 2166  Helsinki            36.0
# 2167  Helsinki            38.6
# 2168  Helsinki            42.4
# 2169  Helsinki            43.0
# 2170  Helsinki            40.5
# 2171  Helsinki            35.7
# 2172  Helsinki            34.6
# 2173  Helsinki            33.1
# 2174  Helsinki            34.4
# 2175  Helsinki            36.1
# 2176  Helsinki            40.6
# 2177  Helsinki            39.8
# 2178  Helsinki            37.2
# 2179  Helsinki            33.0
# 2180  Helsinki            32.4
# 2181  Helsinki            32.3
# 2182  Helsinki            33.5
# 2183  Helsinki            41.9
# 2184  Helsinki            36.0
# 2185  Helsinki            33.9
# 2186  Helsinki            38.8
# 2187  Helsinki            37.0
# 2188  Helsinki            35.3
# ...

# %%
helsinki.plot(kind='box', vert = "False")
miami_beach.plot(kind='box', vert = "False")
tokyo.plot(kind='box', vert = "False")
# Out:
# <Axes: >
